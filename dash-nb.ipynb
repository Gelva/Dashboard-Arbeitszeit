# %%
import dash

# %%
help(dash.html.H2)
# Out:
# Help on class H2 in module dash.html.H2:
#
# class H2(dash.development.base_component.Component)
#  |  H2(children=None, id=undefined, n_clicks=undefined, n_clicks_timestamp=undefined, key=undefined, role=undefined, accessKey=undefined, className=undefined, contentEditable=undefined, contextMenu=undefined, dir=undefined, draggable=undefined, hidden=undefined, lang=undefined, spellCheck=undefined, style=undefined, tabIndex=undefined, title=undefined, loading_state=undefined, **kwargs)
#  |
#  |  A H2 component.
#  |  H2 is a wrapper for the <h2> HTML5 element.
#  |  For detailed attribute info see:
#  |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/h2
#  |
#  |  Keyword arguments:
#  |
#  |  - children (a list of or a singular dash component, string or number; optional):
#  |      The children of this component.
#  |
#  |  - id (string; optional):
#  |      The ID of this component, used to identify dash components in
# ...
